# %% [markdown]
# <a href="https://colab.research.google.com/github/muralidharan-1708/ML-algorithms/blob/main/Statistics_using_Restaurant_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/content/Restaurant.xlsx')
df
# Out:
#           DATE   TIME  INVOICE_NO            ITEM  QUANTITY   RATE  SUB_TOTAL  \
# 0     01.10.23  23.40         174         PAROTTA       4.0   18.0       72.0
# 1     01.10.23  23.40         174         OMLETTE       2.0   18.0       36.0
# 2     01.10.23  23.36         173            DOSA       3.0   20.0       60.0
# 3     01.10.23  23.36         173         PAROTTA       2.0   18.0       36.0
# 4     01.10.23  23.36         173          KALAKI       1.0   15.0       15.0
# ..         ...    ...         ...             ...       ...    ...        ...
# 526  2.10.2285  21.53         146  VEG FRIED RICE       1.0   80.0       80.0
# 527  2.10.2286  21.53         145         PAROTTA       4.0   18.0       72.0
# 528  2.10.2287  21.53         147  BUTTER CHICKEN       1.0  130.0      130.0
# 529  2.10.2288  21.53         147         PAROTTA       2.0   18.0       36.0
# 530  2.10.2289  21.54         148         PAROTTA       3.0   18.0       54.0
#
#      AMOUNT  DAY
# ...

# %%
#Average sales on date 01.10.2023
a = df[df['DATE'] =='01.10.23']
a['AMOUNT'].mean()
# Out:
# np.float64(184.2280701754386)

# %%
#Total amount spent by INVOICE_NO = 117
b = df[df['INVOICE_NO'] == 117]
print(b['AMOUNT'].sum())
# Out:
# 625.0

# %%
#Top 5 item sold
res = df.groupby('ITEM')['SUB_TOTAL'].sum().sort_values(ascending=False).head()
plt.bar(res.index, res.values)
plt.show()

# %%
#Top 5 quantity of item sold
top_quantity = df.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=False).head()
plt.bar(top_quantity.index, top_quantity.values)
plt.show()

# %%
date = df[df['DATE'] =='2.10.2023']
date
# Out:
#           DATE   TIME  INVOICE_NO               ITEM  QUANTITY   RATE  \
# 259  2.10.2023  12.29           1   CHICKEN BIRIYANI       1.0  110.0
# 260  2.10.2023  12.32           2  CHICKEN FICE RICE       1.0  100.0
# 261  2.10.2023  12.32           2            GOBI 65       1.0   60.0
# 262  2.10.2023  12.32           2        EGG PAROTTA       1.0   70.0
# 263  2.10.2023  12.34           3            PAROTTA      12.0   18.0
# 264  2.10.2023  12.34           3       EGG BIRIYANI       1.0   80.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 259      110.0   110.0    2
# 260      100.0   230.0    2
# 261       60.0     NaN    2
# 262       70.0     NaN    2
# 263      216.0   296.0    2
# 264       80.0     NaN    2

# %%
date.sort_values(by="QUANTITY", ascending=True).head()
# Out:
#           DATE   TIME  INVOICE_NO               ITEM  QUANTITY   RATE  \
# 259  2.10.2023  12.29           1   CHICKEN BIRIYANI       1.0  110.0
# 260  2.10.2023  12.32           2  CHICKEN FICE RICE       1.0  100.0
# 261  2.10.2023  12.32           2            GOBI 65       1.0   60.0
# 262  2.10.2023  12.32           2        EGG PAROTTA       1.0   70.0
# 264  2.10.2023  12.34           3       EGG BIRIYANI       1.0   80.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 259      110.0   110.0    2
# 260      100.0   230.0    2
# 261       60.0     NaN    2
# 262       70.0     NaN    2
# 264       80.0     NaN    2

# %%
df.groupby('INVOICE_NO')['AMOUNT'].sum().sort_values(ascending=False).head(1)
# Out:
# INVOICE_NO
# 63    941.0
# Name: AMOUNT, dtype: float64

# %%
df[(df['DATE'] == '01.10.23') & (df['ITEM'] == 'PAROTTA') & (df['TIME'] >= 18.00) & (df['TIME'] <= 21.00)]['QUANTITY'].sum()
# Out:
# np.float64(34.0)
