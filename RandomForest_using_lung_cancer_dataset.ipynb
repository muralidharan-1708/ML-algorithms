# %% [markdown]
# <a href="https://colab.research.google.com/github/muralidharan-1708/ML-algorithms/blob/main/RandomForest_using_lung_cancer_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/survey lung cancer.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
sns.boxplot(x=df['AGE'])
plt.show()

# %%
q1 = df['AGE'].quantile(0.25)
q3 = df['AGE'].quantile(0.75)
iqr = q3 - q1

lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outlier = df[(df['AGE'] < lower_bound) | (df['AGE'] > upper_bound)]
outlier
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 22       F   21        2               1        1              1
# 238      F   38        1               2        1              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 22                 2         2         2         1                  1
# 238                2         2         2         2                  1
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 22          1                    2                      1           1
# 238         2                    2                      1           2
#
#     LUNG_CANCER
# 22           NO
# 238         YES

# %%
# df['AGE'] = np.where(df['AGE'] < 38, df['AGE'].median(), df['AGE'])
# df

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['GENDER'] = le.fit_transform(df['GENDER'])
df
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         0   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         0   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       0   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
from sklearn.model_selection import train_test_split
x = df.drop('LUNG_CANCER', axis=1)
y = df['LUNG_CANCER']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(oob_score = True, n_estimators=5, n_jobs= -1, random_state= 51)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=5, n_jobs=-1, oob_score=True,
#                        random_state=51)

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9193548387096774
